# %% [markdown]
# <a href="https://colab.research.google.com/github/NivethaChinnaraj/project/blob/main/lr.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
df=pd.read_excel("area.xlsx")
print(df)
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
model=linear_model.LinearRegression()
model.fit(df[["area"]],df.price)
model.predict([[3300]])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
plt.scatter(df.area,df.price,color="green",marker="*")
plt.xlabel("area")
plt.ylabel("price")
plt.plot(df.area,model.predict(df[["area"]]),color="Blue")
plt.show()

# %%
model.coef_
# Out:
# array([135.78767123])

# %%
model.intercept_
# Out:
# 180616.43835616432

# %%
d=pd.read_csv("areas.csv")
d
# Out:
#     area        Prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
model.predict(d[["area"]])
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
p=model.predict(d[["area"]])
d["Prices"]=p
d.to_csv("areas.csv",index=False)

# %%
plt.scatter(d.area,d.Prices,color="black",marker="*")
plt.xlabel("area")
plt.ylabel("price")
plt.plot(d.area,model.predict(d[["area"]]),color="red")
plt.show()
